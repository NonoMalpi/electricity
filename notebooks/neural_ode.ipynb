# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import time
import torch

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from torchdiffeq import odeint

from data_collector import Omie
from neural_ode import (ODEfunc, Decoder, LatentODE, RecurrentNN, RunningAverageMeter, 
                        get_random_batch, get_norm_batch, get_norm_batch_with_noise,
                        log_normal_pdf, normal_kl, plot_y_y_pred, plot_prediction_true_scale)

# %%
device = torch.device('cuda:' + str(0) if torch.cuda.is_available() else 'cpu')

# %%
device
# Out:
# device(type='cpu')

# %% [markdown]
# # Data Wrangling

# %%
# uncomment this to obtain day ahead market timeseries
#df = Omie.download_period_file(filename="marginalpdbc", start_year=2016, end_year=2021)

# %%
df = pd.read_csv("day_ahead_market.csv", parse_dates=["date"], 
                  date_parser=lambda x: pd.to_datetime(x, format="%Y-%m-%d"))

df = df[["date", "hour", "spain"]].rename(columns={"spain": "price"})

# remove time change price
df = df[df["hour"] != 25]
# set hour as zero based
df["hour"] = df["hour"] - 1

df["datetime"] = pd.to_datetime(df["date"]) + (df["hour"]).astype('timedelta64[h]')
df.set_index("datetime", inplace=True)
df.sort_index(inplace=True)

# %%
fig, ax = plt.subplots(figsize=(10, 7))
df[["price"]].plot(ax=ax, legend=False)
ax.set_xlabel("Date")
ax.set_ylabel("Day-ahead market price [€]")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 7))
df[["price"]].loc["2016-01-14 20:00:00":"2016-01-25"].plot(ax=ax, legend=False)
ax.set_xlabel("Date")
ax.set_ylabel("Day-ahead market price [€]")
plt.show()

# %% [markdown]
# # NeuralODE - LatentODE framework

# %% [raw]
# # split between train and test
# split_date = "2021-01-01"
# df_train, df_test = df[df["date"] < "2021-01-01"], df[df["date"] >= "2021-01-01"]
#
# # standarise training set
# mean_training = df_train["price"].mean()
# std_training = df_train["price"].std()
# print(f"Mean: {mean_training:.2f}; Std: {std_training:.2f}")
#
# # define training tensor (y_true) -> shape (timesteps, y)
# scaled_training = (df_train["price"] - mean_training) / std_training
# y_true = torch.from_numpy(np.array(scaled_training, dtype=float)).reshape(-1, 1)
# time_tensor = torch.arange(start=0, end=y_true.shape[0], step=1, dtype=torch.float)

# %%
# For the sample augmentation, the mean and std must be computed in each iteration to avoid leakage
df_train_latent = df[df["date"] >= "2020-02-01"]
y_true = df_train_latent["price"]

# %% [markdown]
# ## Simple NeuralODE

# %% [raw]
# # strategy: start with a single point, fit on a small window until convergence, then increase window length and so on
# # https://diffeqflux.sciml.ai/dev/examples/local_minima/#Iterative-Growing-Of-Fits-to-Reduce-Probability-of-Bad-Local-Minima
# s = 3326
# y0 = torch.from_numpy(np.stack([y_true[s]], axis=0)).float()

# %% [raw]
# # configure neural network architecture
# obs_dim = y_true.shape[-1]
# hidden_layer_1 = 16
# hidden_layer_2 = 32
# hidden_layer_3 = 64
# hidden_layer_4 = 32
# hidden_layer_5 = 16
#
# lr = 1e-3
# epochs = 1_000
# time_step = 1
# init_window_length = 3
#
# simple_func = ODEfunc(obs_dim=obs_dim,
#                       hidden_layer_1=hidden_layer_1,
#                       hidden_layer_2=hidden_layer_2,
#                       hidden_layer_3=hidden_layer_3,
#                       hidden_layer_4=hidden_layer_4,
#                       hidden_layer_5=hidden_layer_5
#                      )
#
# optimizer = torch.optim.Adam(simple_func.parameters(), lr=lr)
# loss = torch.nn.MSELoss()
#
# for j in range(4):
#
#     trajectory_time = init_window_length + time_step*j
#     batch = torch.from_numpy(np.stack([y_true[s: s+trajectory_time]], axis=0)).float()
#     samp_ts = time_tensor[:trajectory_time].float()
#
#     print("="*50)
#     start = time.time()
#
#     loss_meter = RunningAverageMeter()
#
#     for i in range(1, epochs+1):
#
#         optimizer.zero_grad()
#
#         y_pred = odeint(func=simple_func, y0=y0, t=samp_ts)
#
#         output = loss(y_pred.reshape(-1), batch.reshape(-1))
#         output.backward()
#
#         optimizer.step()
#         loss_meter.update(output.item())
#
#         if i == 1:
#             log = f"Iteration {j}: {i:04d} | total loss {loss_meter.avg:.6f}"
#             print(log)
#             plot_y_y_pred(y_true=batch, y_pred=y_pred, t=samp_ts)
#
#         if (i % 500 == 0) :
#             end = time.time()
#             training_time = (end-start) / 60
#             log = f"Iteration {j}: {i:04d} | total loss {loss_meter.avg:.6f} | Time: {training_time:.2f} mins"
#             print(log)
#             plot_y_y_pred(y_true=batch, y_pred=y_pred, t=samp_ts)
#             start = time.time()

# %% [markdown]
# ## LatentODE

# %%
# configure neural architecture
obs_dim = 1 # One-dimensional timeseries
latent_dim = 20 # Dimension of the latent space
rnn_hidden = 256 # Dimension of the hidden layer in the recurrentNN encoder 
nbatch = 1 # Number of samples in each minibatch
ode_hidden = 256 # Dimension of the hidden layer in the latent neural ODE
dec_hidden = 256 # Dimenson of the hidden layer in the NN decoder
noise_std = 0.5 # 

lr = 1e-3 # learning rate
epochs = 2_000 # number of epochs
trajectory_time_base = 24 # number of timesteps that enter into the encoder and the neural ODE must integrate
time_step = 6
s = 0

# %%
# define architecture
rnn = RecurrentNN(obs_dim=obs_dim, latent_dim=latent_dim, nhidden=rnn_hidden, nbatch=nbatch).to(device)
latent_func = LatentODE(latent_dim=latent_dim, nhidden=ode_hidden).to(device)
dec = Decoder(latent_dim=latent_dim, obs_dim=obs_dim, nhidden=dec_hidden).to(device)

params = (list(rnn.parameters()) + list(latent_func.parameters()) + list(dec.parameters()))

optimizer = torch.optim.Adam(params, lr=lr)
loss_meter = RunningAverageMeter()

# %%
for j in range(21):
    print(f"Running iteration {j} ... ")
    
    trajectory_time = trajectory_time_base + time_step*j
    # random noise to avoid overfitting?
    #batch, samp_ts, mean, std = get_norm_batch(y_true=y_true, start=s, end=(s+trajectory_time))
    batch, samp_ts, mean, std = get_norm_batch_with_noise(y_true=y_true, start=s, end=(s+trajectory_time), noise_std=noise_std)
    batch = batch.to(device)
    samp_ts = samp_ts.to(device)
    
    
    start = time.time()
    loss_meter = RunningAverageMeter()
    
    for i in range(1, epochs+1):

        optimizer.zero_grad()

        # infer q(z_0) running the RecurrentNN in reversed order
        # possibe dropout?
        h = rnn.init_hidden().to(device)
        for t in reversed(range(trajectory_time)):
            obs = batch[:, t, :]  # obs shape: (nbatch, obs_dim)
            # feed-forward the rnn with the obs for new t and resulting h from previous t evaluation
            out, h = rnn.forward(x=obs, h=h)

        # last out corresponds to t0, shape: (nbatch, latent_dim * 2)
        # latent space parameters are q mean and log var
        qz0_mean, qz0_logvar = out[:, :latent_dim], out[:, latent_dim:]

        # sample z0 from q distribution using reparametrization trick
        # z = mu + sigma * eps, where eps is drawn from a N(0, I)
        epsilon = torch.randn(qz0_mean.size()).to(device)
        z0 = qz0_mean + epsilon * torch.exp(0.5 * qz0_logvar)

        # compute ODE in latent space for samp_ts steps and initial value z0
        # shape after permute: (nbatch, nsample, latent_dim)
        pred_z = odeint(func=latent_func, y0=z0, t=samp_ts).permute(1, 0, 2)

        # decode pred_z from latent space to observation space, pred_x shape: (nbatch, nsamples, obs_dim)
        pred_x = dec(pred_z)

        # compute loss function
        # noise_log_var shape: (nbatch, nsample, nobs)
        noise_std_ = torch.zeros(pred_x.size()).to(device) + noise_std
        noise_logvar = 2. * torch.log(noise_std_).to(device)

        # logpx, shape: (nbatch)
        logpx = log_normal_pdf(x=batch, mean=pred_x, logvar=noise_logvar).sum(-1).sum(-1)

        # p(z0) is assumed to follow N(0, I)
        pz0_mean = torch.zeros(z0.size()).to(device)
        pz0_logvar = torch.zeros(z0.size()).to(device)

        analytic_kl = normal_kl(mu1=qz0_mean, logvar1=qz0_logvar, mu2=pz0_mean, logvar2=pz0_logvar).sum(-1)

        # maximising ELBO is similar to minimising Kullack-Leibler(KL) divergence between Q and posterior
        # p(z|x). However, instead of using the posterior, it can be reformulated using Bayes theorem.
        # Assuming that P(z|x) (posterior) = P(x|z) (likelihood) * P(z) (prior) / P(x)
        # ELBO becomes the log-likelihood p(x|z) - KL(Q,P)| max ELBO = min (-1) ELBO
        # Resources:
        # https://towardsdatascience.com/understanding-variational-autoencoders-vaes-f70510919f73
        # https://en.wikipedia.org/wiki/Evidence_lower_bound
        
        #TODO: Add diff 
        loss = torch.mean(-logpx + analytic_kl, dim=0)

        loss.backward()
        optimizer.step()
        loss_meter.update(loss.item())
        
        if j % 2 == 0: 
            if i == 1:
                print("="*50)
                log = f"Iteration {j}: {i:04d} | total loss {-loss_meter.avg:.6f}"
                print(log)
                plot_y_y_pred(y_true=batch, y_pred=pred_x, t=samp_ts)

            #if i % 400 == 0:
            #    end = time.time()
            #    training_time = (end-start) / 60
            #    log = f"Iteration {j}: {i:04d} | total loss {-loss_meter.avg:.6f} | Time: {training_time:.2f} mins"
            #    print(log)
            #    plot_y_y_pred(y_true=batch, y_pred=pred_x, t=samp_ts)
            #    start = time.time()
                
            if i == epochs:
                
                end = time.time()
                training_time = (end-start) / 60
                log = f"Iteration {j}: {i:04d} | total loss {-loss_meter.avg:.6f} | Time: {training_time:.2f} mins"
                print(log)
                plot_y_y_pred(y_true=batch, y_pred=pred_x, t=samp_ts)
                start = time.time()
                
                print("Prediction")
                
                batch, samp_ts, mean, std = get_norm_batch(y_true=y_true, start=s, end=(s+trajectory_time))
                batch = batch.to(device)
                samp_ts = samp_ts.to(device)
                
                # test learnt dyanmic
                trajectory_time_test = trajectory_time + int(trajectory_time_base*1)
                batch_test = torch.from_numpy(np.stack([y_true[s: s+trajectory_time_test]], axis=0)).float().to(device)
                samp_ts_test = torch.arange(start=s, end=trajectory_time_test, step=1, dtype=torch.float).to(device)
                
                with torch.no_grad():
    
                    h = rnn.init_hidden().to(device)
                    for t in reversed(range(samp_ts.shape[0])):
                        obs = batch[:, t, :]
                        out, h = rnn.forward(x=obs, h=h)

                    qz0_mean, qz0_logvar = out[:, :latent_dim], out[:, latent_dim:]
                    epsilon = torch.randn(qz0_mean.size()).to(device)
                    z0 = qz0_mean + epsilon * torch.exp(0.5 * qz0_logvar)

                    pred_z = odeint(func=latent_func, y0=z0, t=samp_ts_test).permute(1, 0, 2)

                    y_pred = dec(pred_z)
                
                plot_prediction_true_scale(y_true=batch_test, y_pred=y_pred, samp_ts=samp_ts_test, 
                                           t_limit=samp_ts.max().item(), mean=mean, std=std)
# Out:
# Running iteration 0 ...
# ==================================================
# Iteration 0: 0001 | total loss -43.747688
# Iteration 0: 2000 | total loss -12.539323 | Time: 6.83 mins
# Prediction
# Running iteration 1 ...
# Running iteration 2 ...
# ==================================================
# Iteration 2: 0001 | total loss -64.709305
# Iteration 2: 2000 | total loss -14.827531 | Time: 19.53 mins
# Prediction
# Running iteration 3 ...
# Running iteration 4 ...
# ==================================================
# Iteration 4: 0001 | total loss -99.559494
# Iteration 4: 2000 | total loss -18.127731 | Time: 31.00 mins
# Prediction
# Running iteration 5 ...
# Running iteration 6 ...
# ==================================================
# Iteration 6: 0001 | total loss -138.268372
# Iteration 6: 2000 | total loss -47.856656 | Time: 50.48 mins
# Prediction
# Running iteration 7 ...
# Running iteration 8 ...
# ==================================================
# Iteration 8: 0001 | total loss -83.223648
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-95a5817afdb3> in <module>
#      36         # compute ODE in latent space for samp_ts steps and initial value z0
#      37         # shape after permute: (nbatch, nsample, latent_dim)
# ---> 38         pred_z = odeint(func=latent_func, y0=z0, t=samp_ts).permute(1, 0, 2)
#      39
#      40         # decode pred_z from latent space to observation space, pred_x shape: (nbatch, nsamples, obs_dim)
#
# ~/opt/anaconda3/envs/electricity/lib/python3.7/site-packages/torchdiffeq/_impl/odeint.py in odeint(func, y0, t, rtol, atol, method, options, event_fn)
#      75
#      76     if event_fn is None:
# ---> 77         solution = solver.integrate(t)
#      78     else:
#      79         event_t, solution = solver.integrate_until_event(t[0], event_fn)
#
# ~/opt/anaconda3/envs/electricity/lib/python3.7/site-packages/torchdiffeq/_impl/solvers.py in integrate(self, t)
#      28         self._before_integrate(t)
#      29         for i in range(1, len(t)):
# ---> 30             solution[i] = self._advance(t[i])
#      31         return solution
#      32
#
# ~/opt/anaconda3/envs/electricity/lib/python3.7/site-packages/torchdiffeq/_impl/rk_common.py in _advance(self, next_t)
#     192         while next_t > self.rk_state.t1:
#     193             assert n_steps < self.max_num_steps, 'max_num_steps exceeded ({}>={})'.format(n_steps, self.max_num_steps)
# --> 194             self.rk_state = self._adaptive_step(self.rk_state)
#     195             n_steps += 1
#     196         return _interp_evaluate(self.rk_state.interp_coeff, self.rk_state.t0, self.rk_state.t1, next_t)
#
# ~/opt/anaconda3/envs/electricity/lib/python3.7/site-packages/torchdiffeq/_impl/rk_common.py in _adaptive_step(self, rk_state)
#     253         # trigger both. (i.e. interleaving them would be wrong.)
#     254
# --> 255         y1, f1, y1_error, k = _runge_kutta_step(self.func, y0, f0, t0, dt, t1, tableau=self.tableau)
#     256         # dtypes:
#     257         # y1.dtype == self.y0.dtype
#
# ~/opt/anaconda3/envs/electricity/lib/python3.7/site-packages/torchdiffeq/_impl/rk_common.py in _runge_kutta_step(func, y0, f0, t0, dt, t1, tableau)
#      74             perturb = Perturb.NONE
#      75         yi = y0 + k[..., :i + 1].matmul(beta_i * dt).view_as(f0)
# ---> 76         f = func(ti, yi, perturb=perturb)
#      77         k = _UncheckedAssign.apply(k, f, (..., i + 1))
#      78
#
# ~/opt/anaconda3/envs/electricity/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/opt/anaconda3/envs/electricity/lib/python3.7/site-packages/torchdiffeq/_impl/misc.py in forward(self, t, y, perturb)
#     189             # Do nothing.
#     190             pass
# --> 191         return self.base_func(t, y)
#     192
#     193
#
# ~/opt/anaconda3/envs/electricity/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/Desktop/projects/electricity/neural_ode/components.py in forward(self, t, x)
#     111         out = self.layer_2(out)
#     112         out = self.tanh(out)
# --> 113         out = self.layer_3(out)
#     114         return out
#     115
#
# ~/opt/anaconda3/envs/electricity/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     895                 result = hook_result
#     896
# --> 897         if bw_hook:
#     898             result = bw_hook.setup_output_hook(result)
#     899
#
# KeyboardInterrupt:

# %%
# test learnt dyanmic
trajectory_time_test = trajectory_time + int(trajectory_time_base*4)
batch = torch.from_numpy(np.stack([y_true[s: s+trajectory_time]], axis=0)).float()
batch_test = torch.from_numpy(np.stack([y_true[s: s+trajectory_time_test]], axis=0)).float()
samp_ts = time_tensor[:trajectory_time].float()
samp_ts_test = time_tensor[:trajectory_time_test].float()

# %%
with torch.no_grad():
    
    h = rnn.init_hidden()
    for t in reversed(range(samp_ts.shape[0])):
        obs = batch[:, t, :]
        out, h = rnn.forward(x=obs, h=h)
        
    qz0_mean, qz0_logvar = out[:, :latent_dim], out[:, latent_dim:]
    epsilon = torch.randn(qz0_mean.size())
    z0 = qz0_mean + epsilon * torch.exp(0.5 * qz0_logvar)
    
    pred_z = odeint(func=latent_func, y0=z0, t=samp_ts_test).permute(1, 0, 2)
    
    y_pred = dec(pred_z)

# %%
fig, ax = plt.subplots(figsize=(10, 7))
ax.plot(samp_ts_test, batch_test.reshape(-1), color="blue")
ax.plot(samp_ts_test, y_pred.reshape(-1), color="orange")
ax.axvline(x=samp_ts.max().item())
plt.show()
